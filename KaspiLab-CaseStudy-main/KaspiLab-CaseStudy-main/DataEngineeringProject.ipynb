# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Data.csv')
df2 = pd.read_csv('indexInfo.csv')
df3 = pd.read_csv('Processed.csv')

# %%
df1
# Out:
#            key Index        Date         Open         High          Low  \
# 0          579   NYA  12/31/1965   528.690002   528.690002   528.690002
# 1          580   NYA    1/3/1966   527.210022   527.210022   527.210022
# 2          581   NYA    1/4/1966   527.840027   527.840027   527.840027
# 3          582   NYA    1/5/1966   531.119995   531.119995   531.119995
# 4          583   NYA    1/6/1966   532.070007   532.070007   532.070007
# ...        ...   ...         ...          ...          ...          ...
# 112452  113031  N100   5/27/2021  1241.119995  1251.910034  1241.119995
# 112453  113032  N100   5/28/2021  1249.469971  1259.209961  1249.030029
# 112454  113033  N100   5/31/2021  1256.079956  1258.880005  1248.140015
# 112455  113034  N100    6/1/2021  1254.609985  1265.660034  1254.609985
# 112456  113035  N100    6/2/2021  1258.489990  1263.709961  1258.239990
#
#               Close    Adj Close       Volume
# 0        528.690002   528.690002          0.0
# 1        527.210022   527.210022          0.0
# 2        527.840027   527.840027          0.0
# 3        531.119995   531.119995          0.0
# 4        532.070007   532.070007          0.0
# ...             ...          ...          ...
# 112452  1247.069946  1247.069946  379696400.0
# 112453  1256.599976  1256.599976  160773400.0
# 112454  1248.930054  1248.930054   91173700.0
# 112455  1258.579956  1258.579956  155179900.0
# 112456  1263.619995  1263.619995  148465000.0
#
# [112457 rows x 9 columns]

# %%
df2
# Out:
#            Region                          Exchange      Index Currency
# 0   United States           New York Stock Exchange        NYA      USD
# 1   United States                            NASDAQ       IXIC      USD
# 2       Hong Kong          Hong Kong Stock Exchange        HSI      HKD
# 3           China           Shanghai Stock Exchange  000001.SS      CNY
# 4           Japan              Tokyo Stock Exchange       N225      JPY
# 5          Europe                          Euronext       N100      EUR
# 6           China           Shenzhen Stock Exchange  399001.SZ      CNY
# 7          Canada            Toronto Stock Exchange     GSPTSE      CAD
# 8           India  National Stock Exchange of India       NSEI      INR
# 9         Germany          Frankfurt Stock Exchange      GDAXI      EUR
# 10          Korea                    Korea Exchange       KS11      KRW
# 11    Switzerland                SIX Swiss Exchange       SSMI      CHF
# 12         Taiwan             Taiwan Stock Exchange       TWII      TWD
# 13   South Africa       Johannesburg Stock Exchange    J203.JO      ZAR

# %%
df3
# Out:
#            key    Index        Date          Open          High           Low  \
# 0            1      HSI  12/31/1986   2568.300049   2568.300049   2568.300049
# 1            2      HSI    1/2/1987   2540.100098   2540.100098   2540.100098
# 2            3      HSI    1/5/1987   2552.399902   2552.399902   2552.399902
# 3            4      HSI    1/6/1987   2583.899902   2583.899902   2583.899902
# 4            5      HSI    1/7/1987   2607.100098   2607.100098   2607.100098
# ...        ...      ...         ...           ...           ...           ...
# 104221  104222  J203.JO   5/27/2021  66108.226560  66940.250000  66102.546880
# 104222  104223  J203.JO   5/28/2021  66940.250000  67726.562500  66794.609380
# 104223  104224  J203.JO   5/31/2021  67554.859380  68140.851560  67554.859380
# 104224    7000      NYA   5/11/2021  27837.039060  27837.279300  27582.230470
# 104225   11000      HSI   5/11/2021    553.320007    553.320007    553.320007
#
#                Close     Adj Close      Volume     CloseUSD
# 0        2568.300049   2568.300049           0   333.879006
# 1        2540.100098   2540.100098           0   330.213013
# 2        2552.399902   2552.399902           0   331.811987
# 3        2583.899902   2583.899902           0   335.906987
# 4        2607.100098   2607.100098           0   338.923013
# ...              ...           ...         ...          ...
# 104221  66940.250000  66940.250000           0  4685.817500
# 104222  67554.859380  67554.859380           0  4728.840157
# 104223  67964.039060  67964.039060           0  4757.482734
# 104224  27718.199220  27718.199220  1540963800  3603.365899
# 104225    553.320007    553.320007           0   553.320007
#
# [104226 rows x 10 columns]

# %%
df1[df1.isna().any(axis=1)]
# Out:
#            key Index        Date  Open  High  Low  Close  Adj Close  Volume
# 88       29232   HSI   9/21/1994   NaN   NaN  NaN    NaN        NaN     NaN
# 177      29414   HSI    6/2/1995   NaN   NaN  NaN    NaN        NaN     NaN
# 266      29685   HSI   6/17/1996   NaN   NaN  NaN    NaN        NaN     NaN
# 292        868   NYA   2/23/1967   NaN   NaN  NaN    NaN        NaN     NaN
# 444      29956   HSI    7/1/1997   NaN   NaN  NaN    NaN        NaN     NaN
# ...        ...   ...         ...   ...   ...  ...    ...        ...     ...
# 108316  108895  N100   3/28/2005   NaN   NaN  NaN    NaN        NaN     NaN
# 108511  109090  N100  12/26/2005   NaN   NaN  NaN    NaN        NaN     NaN
# 110051  110630  N100    1/2/2012   NaN   NaN  NaN    NaN        NaN     NaN
# 110643  111222  N100    5/1/2014   NaN   NaN  NaN    NaN        NaN     NaN
# 112090  112669  N100  12/25/2019   NaN   NaN  NaN    NaN        NaN     NaN
#
# [2204 rows x 9 columns]

# %%
df3[(df3['Index'] == 'HSI') & (df3['Date'] == '1996-09-21')]
# Out:
# Empty DataFrame
# Columns: [key, Index, Date, Open, High, Low, Close, Adj Close, Volume, CloseUSD]
# Index: []

# %%
df3[df3.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [key, Index, Date, Open, High, Low, Close, Adj Close, Volume, CloseUSD]
# Index: []

# %%
df3[df3.duplicated() == False]
# Out:
#            key    Index        Date          Open          High           Low  \
# 0            1      HSI  12/31/1986   2568.300049   2568.300049   2568.300049
# 1            2      HSI    1/2/1987   2540.100098   2540.100098   2540.100098
# 2            3      HSI    1/5/1987   2552.399902   2552.399902   2552.399902
# 3            4      HSI    1/6/1987   2583.899902   2583.899902   2583.899902
# 4            5      HSI    1/7/1987   2607.100098   2607.100098   2607.100098
# ...        ...      ...         ...           ...           ...           ...
# 104221  104222  J203.JO   5/27/2021  66108.226560  66940.250000  66102.546880
# 104222  104223  J203.JO   5/28/2021  66940.250000  67726.562500  66794.609380
# 104223  104224  J203.JO   5/31/2021  67554.859380  68140.851560  67554.859380
# 104224    7000      NYA   5/11/2021  27837.039060  27837.279300  27582.230470
# 104225   11000      HSI   5/11/2021    553.320007    553.320007    553.320007
#
#                Close     Adj Close      Volume     CloseUSD
# 0        2568.300049   2568.300049           0   333.879006
# 1        2540.100098   2540.100098           0   330.213013
# 2        2552.399902   2552.399902           0   331.811987
# 3        2583.899902   2583.899902           0   335.906987
# 4        2607.100098   2607.100098           0   338.923013
# ...              ...           ...         ...          ...
# 104221  66940.250000  66940.250000           0  4685.817500
# 104222  67554.859380  67554.859380           0  4728.840157
# 104223  67964.039060  67964.039060           0  4757.482734
# 104224  27718.199220  27718.199220  1540963800  3603.365899
# 104225    553.320007    553.320007           0   553.320007
#
# [104226 rows x 10 columns]

# %%
df1.isnull().sum().sum()
# Out:
# 13224

# %%
df3.drop_duplicates(subset='key', inplace=True)

# %%
df3
# Out:
#            key    Index        Date          Open          High           Low  \
# 0            1      HSI  12/31/1986   2568.300049   2568.300049   2568.300049
# 1            2      HSI    1/2/1987   2540.100098   2540.100098   2540.100098
# 2            3      HSI    1/5/1987   2552.399902   2552.399902   2552.399902
# 3            4      HSI    1/6/1987   2583.899902   2583.899902   2583.899902
# 4            5      HSI    1/7/1987   2607.100098   2607.100098   2607.100098
# ...        ...      ...         ...           ...           ...           ...
# 104219  104220  J203.JO   5/25/2021  66054.921880  66812.453130  66022.976560
# 104220  104221  J203.JO   5/26/2021  66076.679690  66446.367190  66030.351560
# 104221  104222  J203.JO   5/27/2021  66108.226560  66940.250000  66102.546880
# 104222  104223  J203.JO   5/28/2021  66940.250000  67726.562500  66794.609380
# 104223  104224  J203.JO   5/31/2021  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049       0   333.879006
# 1        2540.100098   2540.100098       0   330.213013
# 2        2552.399902   2552.399902       0   331.811987
# 3        2583.899902   2583.899902       0   335.906987
# 4        2607.100098   2607.100098       0   338.923013
# ...              ...           ...     ...          ...
# 104219  66076.679690  66076.679690       0  4625.367578
# 104220  66108.226560  66108.226560       0  4627.575859
# 104221  66940.250000  66940.250000       0  4685.817500
# 104222  67554.859380  67554.859380       0  4728.840157
# 104223  67964.039060  67964.039060       0  4757.482734
#
# [104224 rows x 10 columns]

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1
# Out:
#            key Index        Date         Open         High          Low  \
# 0          579   NYA  12/31/1965   528.690002   528.690002   528.690002
# 1          580   NYA    1/3/1966   527.210022   527.210022   527.210022
# 2          581   NYA    1/4/1966   527.840027   527.840027   527.840027
# 3          582   NYA    1/5/1966   531.119995   531.119995   531.119995
# 4          583   NYA    1/6/1966   532.070007   532.070007   532.070007
# ...        ...   ...         ...          ...          ...          ...
# 112452  113031  N100   5/27/2021  1241.119995  1251.910034  1241.119995
# 112453  113032  N100   5/28/2021  1249.469971  1259.209961  1249.030029
# 112454  113033  N100   5/31/2021  1256.079956  1258.880005  1248.140015
# 112455  113034  N100    6/1/2021  1254.609985  1265.660034  1254.609985
# 112456  113035  N100    6/2/2021  1258.489990  1263.709961  1258.239990
#
#               Close    Adj Close       Volume
# 0        528.690002   528.690002          0.0
# 1        527.210022   527.210022          0.0
# 2        527.840027   527.840027          0.0
# 3        531.119995   531.119995          0.0
# 4        532.070007   532.070007          0.0
# ...             ...          ...          ...
# 112452  1247.069946  1247.069946  379696400.0
# 112453  1256.599976  1256.599976  160773400.0
# 112454  1248.930054  1248.930054   91173700.0
# 112455  1258.579956  1258.579956  155179900.0
# 112456  1263.619995  1263.619995  148465000.0
#
# [110253 rows x 9 columns]

# %%
for item in df1['Index'].unique():
    print('Shape in df1 {} and index = {}'.format(df1[df1['Index'] == item].shape, item))
    print('Shape in df3 {} and index = {}'.format(df3[df3['Index'] == item].shape, item))
    print('')
# Out:
# Shape in df1 (13947, 9) and index = NYA
# Shape in df3 (13947, 10) and index = NYA
#
# Shape in df1 (12690, 9) and index = IXIC
# Shape in df3 (12690, 10) and index = IXIC
#
# Shape in df1 (8492, 9) and index = HSI
# Shape in df3 (8492, 10) and index = HSI
#
# Shape in df1 (5791, 9) and index = 000001.SS
# Shape in df3 (5791, 10) and index = 000001.SS
#
# Shape in df1 (10526, 9) and index = GSPTSE
# Shape in df3 (10526, 10) and index = GSPTSE
#
# Shape in df1 (5760, 9) and index = 399001.SZ
# Shape in df3 (5760, 10) and index = 399001.SZ
#
# Shape in df1 (3346, 9) and index = NSEI
# Shape in df3 (3346, 10) and index = NSEI
#
# Shape in df1 (8438, 9) and index = GDAXI
# Shape in df3 (8438, 10) and index = GDAXI
#
# Shape in df1 (6029, 9) and index = KS11
# Shape in df3 (0, 10) and index = KS11
#
# Shape in df1 (7671, 9) and index = SSMI
# Shape in df3 (7671, 10) and index = SSMI
#
# Shape in df1 (5869, 9) and index = TWII
# Shape in df3 (5869, 10) and index = TWII
#
# Shape in df1 (2346, 9) and index = J203.JO
# Shape in df3 (2346, 10) and index = J203.JO
#
# Shape in df1 (13874, 9) and index = N225
# Shape in df3 (13874, 10) and index = N225
#
# Shape in df1 (5474, 9) and index = N100
# Shape in df3 (5474, 10) and index = N100

# %%
def v_not_processed(df1, df2, df3):
    df1 = df1.dropna()
    for item in df1['Index'].unique():
        if (df1[df1['Index'] == item].shape[0]) != (df3[df3['Index'] == item].shape[0]):
            return df1[df1['Index'] == item], df2[df2['Index'] == item]['Region'].values[0]

# %%
dataFrame, region = v_not_processed(df1, df2, df3)
print('Region: {}'.format(region))
print(dataFrame[:20])
# Out:
# Region: Korea
#          key Index        Date        Open        High         Low  \
# 70047  70621  KS11  12/11/1996  705.989990  709.479980  704.429993
# 70048  70622  KS11  12/12/1996  705.109985  706.010010  688.739990
# 70049  70623  KS11  12/13/1996  690.440002  695.719971  677.640015
# 70050  70624  KS11  12/16/1996  686.969971  686.969971  667.710022
# 70051  70625  KS11  12/17/1996  675.349976  680.090027  660.390015
# 70052  70626  KS11  12/18/1996  662.070007  671.429993  655.469971
# 70053  70627  KS11  12/19/1996  668.130005  690.969971  668.130005
# 70054  70628  KS11  12/20/1996  695.330017  703.510010  692.469971
# 70055  70629  KS11  12/23/1996  691.979980  697.119995  684.809998
# 70056  70630  KS11  12/24/1996  683.109985  687.059998  677.559998
# 70058  70632  KS11  12/26/1996  676.210022  676.210022  655.239990
# 70059  70633  KS11  12/27/1996  654.820007  657.039978  643.570007
# 70064  70638  KS11    1/3/1997  647.669983  655.700012  635.409973
# 70065  70639  KS11    1/6/1997  637.979980  637.979980  625.010010
# 70066  70640  KS11    1/7/1997  622.450012  627.609985  609.119995
# 70067  70641  KS11    1/8/1997  608.530029  623.390015  600.559998
# 70068  70642  KS11    1/9/1997  619.099976  640.809998  612.409973
# 70069  70643  KS11   1/10/1997  637.989990  653.590027  636.809998
# 70070  70644  KS11   1/13/1997  659.809998  664.950012  655.739990
# 70071  70645  KS11   1/14/1997  656.669983  687.659973  656.669983
#
#             Close   Adj Close   Volume
# 70047  704.679993  704.679993  28000.0
# 70048  689.380005  689.380005  25900.0
# 70049  689.070007  689.070007  26500.0
# 70050  673.919983  673.919983  22800.0
# 70051  663.349976  663.349976  31600.0
# 70052  661.390015  661.390015  31500.0
# 70053  690.969971  690.969971  30400.0
# 70054  700.869995  700.869995  30000.0
# 70055  684.809998  684.809998  21500.0
# 70056  677.760010  677.760010  23800.0
# 70058  659.010010  659.010010  25500.0
# 70059  651.219971  651.219971  35100.0
# 70064  653.789978  653.789978  13900.0
# 70065  626.869995  626.869995  17600.0
# 70066  611.049988  611.049988  24100.0
# 70067  621.409973  621.409973  34200.0
# 70068  639.869995  639.869995  36100.0
# 70069  648.690002  648.690002  36500.0
# 70070  659.539978  659.539978  28700.0
# 70071  686.590027  686.590027  36600.0

# %%
def v_processed(region, date, df2, df3):
    month = date.split('/')[0]
    year = date.split('/')[1]
    index = list(df2[df2['Region'] == region]['Index'].values)
    frames = []
    for item in index:
        frames.append(df3[(df3['Index'] == item) & (df3['Date'].apply(lambda x: x.split('/')[0]) == month ) & 
                          (df3['Date'].apply(lambda x: x.split('/')[2]) == year)])
    dataFrame = pd.concat(frames)
    max_open = max(dataFrame['Open'])
    max_index = dataFrame[dataFrame['Open'] == max_open]['Index'].values[0]
    min_close = min(dataFrame['Low'])
    min_index = dataFrame[dataFrame['Low'] == min_close]['Index'].values[0]
    currency = df2[df2['Region'] == region]['Currency'].values[0]
    max_open_exchange = df2[(df2['Region'] == region) & (df2['Index'] == max_index)]['Exchange'].values[0]
    min_close_exchange = df2[(df2['Region'] == region) & (df2['Index'] == min_index)]['Exchange'].values[0]
    return dataFrame, max_open, min_close, currency, max_open_exchange, min_close_exchange

# %%
region = 'China'
date = '5/2021'
dataFrame, max_open, min_close, currency, max_open_exchange, min_close_exchange = v_processed(region,date,df2,df3)

# %%
max_open_exchange
# Out:
# 'Shenzhen Stock Exchange'

# %%
dataFrame
# Out:
#          key      Index       Date          Open          High           Low  \
# 40902  40903  000001.SS   5/6/2021   3446.070068   3471.239990   3426.850098
# 40903  40904  000001.SS   5/7/2021   3446.409912   3457.889893   3416.780029
# 40904  40905  000001.SS  5/10/2021   3423.590088   3429.739990   3401.929932
# 40905  40906  000001.SS  5/11/2021   3406.600098   3448.100098   3384.699951
# 40906  40907  000001.SS  5/12/2021   3429.750000   3466.370117   3428.389893
# 40907  40908  000001.SS  5/13/2021   3432.139893   3448.020020   3418.379883
# 40908  40909  000001.SS  5/14/2021   3436.090088   3490.639893   3422.560059
# 40909  40910  000001.SS  5/17/2021   3490.409912   3530.510010   3490.139893
# 40910  40911  000001.SS  5/18/2021   3520.649902   3529.010010   3510.860107
# 40911  40912  000001.SS  5/19/2021   3521.110107   3521.110107   3503.820068
# 40912  40913  000001.SS  5/20/2021   3500.879883   3517.739990   3486.070068
# 40913  40914  000001.SS  5/21/2021   3510.840088   3518.379883   3479.669922
# 40914  40915  000001.SS  5/24/2021   3486.270020   3498.300049   3469.870117
# 40915  40916  000001.SS  5/25/2021   3502.540039   3584.580078   3502.439941
# 40916  40917  000001.SS  5/26/2021   3586.840088   3603.489990   3585.370117
# 40917  40918  000001.SS  5/27/2021   3585.729980   3626.360107   3579.260010
# 40918  40919  000001.SS  5/28/2021   3610.770020   3622.179932   3582.360107
# 40919  40920  000001.SS  5/31/2021   3600.070068   3615.659912   3580.649902
# 66008  66009  399001.SZ   5/6/2021  14355.400390  14398.580080  14088.040040
# 66009  66010  399001.SZ   5/7/2021  14243.709960  14280.040040  13933.809570
# 66010  66011  399001.SZ  5/10/2021  13945.780270  14035.599610  13828.820310
# 66011  66012  399001.SZ  5/11/2021  13814.280270  13996.700200  13696.730470
# 66012  66013  399001.SZ  5/12/2021  13922.150390  14078.330080  13872.099610
# 66013  66014  399001.SZ  5/13/2021  13907.179690  14027.549810  13866.110350
# 66014  66015  399001.SZ  5/14/2021  13960.330080  14214.139650  13872.629880
# 66015  66016  399001.SZ  5/17/2021  14234.700200  14538.759770  14234.700200
# 66016  66017  399001.SZ  5/18/2021  14462.410160  14497.900390  14345.990230
# 66017  66018  399001.SZ  5/19/2021  14399.759770  14544.200200  14359.019530
# 66018  66019  399001.SZ  5/20/2021  14455.610350  14582.400390  14431.799810
# 66019  66020  399001.SZ  5/21/2021  14582.070310  14634.599610  14386.120120
# 66020  66021  399001.SZ  5/24/2021  14436.360350  14506.610350  14295.480470
# 66021  66022  399001.SZ  5/25/2021  14533.950200  14862.190430  14509.780270
# 66022  66023  399001.SZ  5/26/2021  14850.280270  14860.639650  14762.200200
# 66023  66024  399001.SZ  5/27/2021  14796.049810  14955.299810  14720.669920
# 66024  66025  399001.SZ  5/28/2021  14899.330080  14977.250000  14778.820310
# 66025  66026  399001.SZ  5/31/2021  14874.889650  14996.379880  14836.150390
#
#               Close     Adj Close   Volume     CloseUSD
# 40902   3441.280029   3441.280029   310400   550.604805
# 40903   3418.870117   3418.870117   353800   547.019219
# 40904   3427.989990   3427.989990   374200   548.478398
# 40905   3441.850098   3441.850098   350900   550.696016
# 40906   3462.750000   3462.750000   311400   554.040000
# 40907   3429.540039   3429.540039   319300   548.726406
# 40908   3490.379883   3490.379883   337000   558.460781
# 40909   3517.620117   3517.620117   322100   562.819219
# 40910   3529.010010   3529.010010   271300   564.641602
# 40911   3510.959961   3510.959961   278300   561.753594
# 40912   3506.939941   3506.939941   326000   561.110391
# 40913   3486.560059   3486.560059   283800   557.849609
# 40914   3497.280029   3497.280029   289500   559.564805
# 40915   3581.340088   3581.340088   341200   573.014414
# 40916   3593.360107   3593.360107   342000   574.937617
# 40917   3608.850098   3608.850098   309600   577.416016
# 40918   3600.780029   3600.780029   349200   576.124805
# 40919   3615.479980   3615.479980   331500   578.476797
# 66008  14210.599610  14210.599610  1432900  2273.695938
# 66009  13933.809570  13933.809570  1578100  2229.409531
# 66010  13917.969730  13917.969730  1538200  2226.875157
# 66011  13966.790040  13966.790040  1533800  2234.686406
# 66012  14064.870120  14064.870120  1262800  2250.379219
# 66013  13917.650390  13917.650390  1367600  2226.824062
# 66014  14208.780270  14208.780270  1530900  2273.404843
# 66015  14456.540040  14456.540040  1463900  2313.046406
# 66016  14450.599610  14450.599610  1186900  2312.095938
# 66017  14484.450200  14484.450200  1243900  2317.512032
# 66018  14535.099610  14535.099610  1438500  2325.615938
# 66019  14417.459960  14417.459960  1287800  2306.793594
# 66020  14506.610350  14506.610350  1306300  2321.057656
# 66021  14846.450200  14846.450200  1531600  2375.432032
# 66022  14793.679690  14793.679690  1546400  2366.988750
# 66023  14897.190430  14897.190430  1502100  2383.550469
# 66024  14852.879880  14852.879880  1651600  2376.460781
# 66025  14996.379880  14996.379880  1460400  2399.420781

# %%
fig, ax = plt.subplots()
for item in list(dataFrame['Index'].unique()):
    ax.plot(dataFrame[dataFrame['Index'] == item]['Date'].apply(lambda x: x.split('/')[1]), 
            dataFrame[dataFrame['Index'] == item]['Open'],
            label=item, markersize=8)
ax.legend()
ax.set_xlabel('Days')
ax.set_ylabel(currency)
ax.set_title('{}. максимальная цена в момент даты открытия на {}'.format(region, date))
fig.savefig('my_plot1.png')

# %%
fig, ax = plt.subplots()
for item in list(dataFrame['Index'].unique()):
    ax.plot(dataFrame[dataFrame['Index'] == item]['Date'].apply(lambda x: x.split('/')[1]), 
            dataFrame[dataFrame['Index'] == item]['Low'],
            label=item, markersize=8)
ax.legend()
ax.set_xlabel('Days')
ax.set_ylabel(currency)
ax.set_title('{}. минимальная цена во время торговли на {}'.format(region, date))
fig.savefig('my_plot2.png')
